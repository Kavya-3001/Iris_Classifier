# %% [markdown]
# The iris Classifier

# %% [markdown]
# import and load the dataset

# %%
from sklearn.datasets import load_iris
iris=load_iris()
x=iris.data
y=iris.target
print(iris.feature_names,iris.target_names)
print(len(x))

# %% [markdown]
# splits the dataset into training and testing dataset

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# Created train and decision model

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(random_state=42)

# %%
model.fit(x_train,y_train)

# %% [markdown]
# Make prediction on the test set

# %%
y_pred=model.predict(x_test)
print("predictions",y_pred[:5])
print("True lables",y_test[:5])

# %% [markdown]
# Evaluvate decision tree model accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)

# %% [markdown]
# Make prediction with the K-NN model and make prediction

# %%
from sklearn.neighbors import KNeighborsClassifier
model2=KNeighborsClassifier(n_neighbors=5)
model2.fit(x_train,y_train)
y_pred2=model2.predict(x_test)
print("k-NN accuracy:",accuracy_score(y_test,y_pred2))

# %% [markdown]
# Tuning the model(an example of overfitting)

# %%
model3=DecisionTreeClassifier(max_depth=3,random_state=42)
model3.fit(x_train,y_train)
y_pred3=model3.predict(x_test)
print("The Prediction:",y_pred3)
